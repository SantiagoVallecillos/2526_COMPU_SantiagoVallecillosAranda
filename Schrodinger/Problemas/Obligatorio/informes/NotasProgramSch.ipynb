# %% [markdown]
# # Ecuación de Schrödinger - Notas durante la programación
#
# En primer lugar y para aclararme voy a ir paso por paso con los algoritmos que me dan en los apuntes para descifrar qué necesito y qué tengo que hacer. Eso lo traduciré luego a código.
#
# 1. Dar los parámetros iniciales (N, $n_{ciclos} y $\lambda$). Generar $\tilde{s}$, $\tilde{k}_0$, $\tilde{V}_j$, $\Phi_{j,0}$, $\alpha$.
