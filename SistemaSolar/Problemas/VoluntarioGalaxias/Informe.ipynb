# %% [markdown]
# # Formación de Galaxias a partir de Sistemas Solares.
# Autor: Santiago Vallecillos Aranda.
#
# ## 1. Introducción.
#
# En el presente informe se estudia la formación de galaxias, considerando como condiciones iniciales la presencia de un agujero negro supermasivo y diversos sistemas solares a su alrededor con variadas condiciones iniciales.

# %% [markdown]
# ## 2. Fundamento teórico.

# %% [markdown]
# ## 3. Datos.
#
# En primer lugar, hubo que recopilar datos sobre las masas de el agujero negro supermasivo que se sitúa en el centro de la Vía Láctea y de nuestro sistema solar.
#
# 1. El agujero negro masivo de nuestra galaxia tiene una masa aproximada de $8,2·10^{36}$ kg.
# 2. La masa del Sistema Solar es, aproximadamente, $1,989·10^{30}$ kg. Es de destacar que la mayor parte de la masa de nuestro sistema solar la concentra el propio Sol.
