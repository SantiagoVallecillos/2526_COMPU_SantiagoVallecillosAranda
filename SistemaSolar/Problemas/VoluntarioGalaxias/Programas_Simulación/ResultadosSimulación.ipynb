# %% [markdown]
# ## Registro de resultados de simulaciones.
#
# La simulación en todos los casos se realizó con las mismas condiciciones iniciales. Se realizó con optimización por OPEN MP (PRAGMA) y sin ella tanto en mi PC personal como en el cluster ).
